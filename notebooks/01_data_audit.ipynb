# %% [markdown]
# # 01 - Data Audit
#
# ## Objective
# This notebook performs the initial inspection of the telco dataset.
# At this stage, the goal is to understand its structure, quality, and possible target-related columns.
#
# ## Key Questions
# - What does one row represent?
# - What columns are available?
# - What are the data types?
# - Are there missing values or duplicates?
# - Which columns may be identifiers?
# - Which columns may contain target or post-outcome information?

# %%
import pandas as pd
import numpy as np

pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", 200)

# %% [markdown]
# ## Load the Dataset
#
# In this section, we load the raw telco dataset from the project folder.
#
# We do not make any changes to the data yet.
# The purpose is only to read the file successfully and preview the first rows.

# %%
df = pd.read_csv("../data/raw/telco.csv")
df.head()
# Out:
#   Customer ID  Gender  Age Under 30 Senior Citizen Married Dependents  \
# 0  8779-QRDMV    Male   78       No            Yes      No         No
# 1  7495-OOKFY  Female   74       No            Yes     Yes        Yes
# 2  1658-BYGOY    Male   71       No            Yes      No        Yes
# 3  4598-XLKNJ  Female   78       No            Yes     Yes        Yes
# 4  4846-WHAFZ  Female   80       No            Yes     Yes        Yes
#
#    Number of Dependents        Country       State         City  Zip Code  \
# 0                     0  United States  California  Los Angeles     90022
# 1                     1  United States  California  Los Angeles     90063
# 2                     3  United States  California  Los Angeles     90065
# 3                     1  United States  California    Inglewood     90303
# 4                     1  United States  California     Whittier     90602
#
#     Latitude   Longitude  Population Quarter Referred a Friend  \
# 0  34.023810 -118.156582       68701      Q3                No
# 1  34.044271 -118.185237       55668      Q3               Yes
# 2  34.108833 -118.229715       47534      Q3                No
# 3  33.936291 -118.332639       27778      Q3               Yes
# 4  33.972119 -118.020188       26265      Q3               Yes
#
#    Number of Referrals  Tenure in Months    Offer Phone Service  \
# 0                    0                 1      NaN            No
# 1                    1                 8  Offer E           Yes
# 2                    0                18  Offer D           Yes
# 3                    1                25  Offer C           Yes
# 4                    1                37  Offer C           Yes
#
#    Avg Monthly Long Distance Charges Multiple Lines Internet Service  \
# 0                               0.00             No              Yes
# 1                              48.85            Yes              Yes
# 2                              11.33            Yes              Yes
# 3                              19.76             No              Yes
# 4                               6.33            Yes              Yes
#
#   Internet Type  Avg Monthly GB Download Online Security Online Backup  \
# 0           DSL                        8              No            No
# 1   Fiber Optic                       17              No           Yes
# 2   Fiber Optic                       52              No            No
# 3   Fiber Optic                       12              No           Yes
# 4   Fiber Optic                       14              No            No
#
#   Device Protection Plan Premium Tech Support Streaming TV Streaming Movies  \
# 0                    Yes                   No           No              Yes
# 1                     No                   No           No               No
# 2                     No                   No          Yes              Yes
# 3                    Yes                   No          Yes              Yes
# 4                     No                   No           No               No
#
#   Streaming Music Unlimited Data        Contract Paperless Billing  \
# 0              No             No  Month-to-Month               Yes
# 1              No            Yes  Month-to-Month               Yes
# 2             Yes            Yes  Month-to-Month               Yes
# 3              No            Yes  Month-to-Month               Yes
# 4              No            Yes  Month-to-Month               Yes
#
#     Payment Method  Monthly Charge  Total Charges  Total Refunds  \
# 0  Bank Withdrawal           39.65          39.65           0.00
# 1      Credit Card           80.65         633.30           0.00
# 2  Bank Withdrawal           95.45        1752.55          45.61
# 3  Bank Withdrawal           98.50        2514.50          13.43
# 4  Bank Withdrawal           76.50        2868.15           0.00
#
#    Total Extra Data Charges  Total Long Distance Charges  Total Revenue  \
# 0                        20                         0.00          59.65
# 1                         0                       390.80        1024.10
# 2                         0                       203.94        1910.88
# 3                         0                       494.00        2995.07
# 4                         0                       234.21        3102.36
#
#    Satisfaction Score Customer Status Churn Label  Churn Score  CLTV  \
# 0                   3         Churned         Yes           91  5433
# 1                   3         Churned         Yes           69  5302
# 2                   2         Churned         Yes           81  3179
# 3                   2         Churned         Yes           88  5337
# 4                   2         Churned         Yes           67  2793
#
#     Churn Category                  Churn Reason
# 0       Competitor  Competitor offered more data
# 1       Competitor  Competitor made better offer
# 2       Competitor  Competitor made better offer
# 3  Dissatisfaction     Limited range of services
# 4            Price            Extra data charges

# %% [markdown]
# ## Dataset Shape and Column Names
#
# This step helps us understand the overall size of the dataset and see all available columns.
#
# We want to know:
# - how many observations we have
# - how many features are available
# - how the columns are named

# %%
print("Shape:", df.shape)
print("\nColumns:")
print(df.columns.tolist())
# Out:
# Shape: (7043, 50)
#
# Columns:
# ['Customer ID', 'Gender', 'Age', 'Under 30', 'Senior Citizen', 'Married', 'Dependents', 'Number of Dependents', 'Country', 'State', 'City', 'Zip Code', 'Latitude', 'Longitude', 'Population', 'Quarter', 'Referred a Friend', 'Number of Referrals', 'Tenure in Months', 'Offer', 'Phone Service', 'Avg Monthly Long Distance Charges', 'Multiple Lines', 'Internet Service', 'Internet Type', 'Avg Monthly GB Download', 'Online Security', 'Online Backup', 'Device Protection Plan', 'Premium Tech Support', 'Streaming TV', 'Streaming Movies', 'Streaming Music', 'Unlimited Data', 'Contract', 'Paperless Billing', 'Payment Method', 'Monthly Charge', 'Total Charges', 'Total Refunds', 'Total Extra Data Charges', 'Total Long Distance Charges', 'Total Revenue', 'Satisfaction Score', 'Customer Status', 'Churn Label', 'Churn Score', 'CLTV', 'Churn Category', 'Churn Reason']

# %% [markdown]
# ## Data Types and Basic Column Profiling
#
# In this section, we inspect:
# - data types
# - non-null counts
# - null counts
# - null percentages
# - number of unique values
#
# This gives us a first structured view of the dataset and helps identify columns that may need closer inspection later.

# %%
profile_df = pd.DataFrame({
    "column": df.columns,
    "dtype": df.dtypes.values,
    "non_null_count": df.notna().sum().values,
    "null_count": df.isna().sum().values,
    "null_pct": (df.isna().mean().values * 100).round(2),
    "n_unique": df.nunique(dropna=False).values
})

profile_df.sort_values(by="null_count", ascending=False)
# Out:
#                                column    dtype  non_null_count  null_count  \
# 49                       Churn Reason   object            1869        5174
# 48                     Churn Category   object            1869        5174
# 19                              Offer   object            3166        3877
# 24                      Internet Type   object            5517        1526
# 36                     Payment Method   object            7043           0
# 28             Device Protection Plan   object            7043           0
# 29               Premium Tech Support   object            7043           0
# 30                       Streaming TV   object            7043           0
# 31                   Streaming Movies   object            7043           0
# 32                    Streaming Music   object            7043           0
# 33                     Unlimited Data   object            7043           0
# 34                           Contract   object            7043           0
# 35                  Paperless Billing   object            7043           0
# 37                     Monthly Charge  float64            7043           0
# 26                    Online Security   object            7043           0
# 38                      Total Charges  float64            7043           0
# 39                      Total Refunds  float64            7043           0
# 40           Total Extra Data Charges    int64            7043           0
# 41        Total Long Distance Charges  float64            7043           0
# 42                      Total Revenue  float64            7043           0
# 43                 Satisfaction Score    int64            7043           0
# 44                    Customer Status   object            7043           0
# 45                        Churn Label   object            7043           0
# 46                        Churn Score    int64            7043           0
# 47                               CLTV    int64            7043           0
# 27                      Online Backup   object            7043           0
# 0                         Customer ID   object            7043           0
# 1                              Gender   object            7043           0
# 11                           Zip Code    int64            7043           0
# 2                                 Age    int64            7043           0
# 3                            Under 30   object            7043           0
# 4                      Senior Citizen   object            7043           0
# 5                             Married   object            7043           0
# 6                          Dependents   object            7043           0
# 7                Number of Dependents    int64            7043           0
# 8                             Country   object            7043           0
# 9                               State   object            7043           0
# 10                               City   object            7043           0
# 12                           Latitude  float64            7043           0
# 23                   Internet Service   object            7043           0
# 13                          Longitude  float64            7043           0
# 14                         Population    int64            7043           0
# 15                            Quarter   object            7043           0
# 16                  Referred a Friend   object            7043           0
# 17                Number of Referrals    int64            7043           0
# 18                   Tenure in Months    int64            7043           0
# 20                      Phone Service   object            7043           0
# 21  Avg Monthly Long Distance Charges  float64            7043           0
# 22                     Multiple Lines   object            7043           0
# 25            Avg Monthly GB Download    int64            7043           0
#
#     null_pct  n_unique
# 49     73.46        21
# 48     73.46         6
# 19     55.05         6
# 24     21.67         4
# 36      0.00         3
# 28      0.00         2
# 29      0.00         2
# 30      0.00         2
# 31      0.00         2
# 32      0.00         2
# 33      0.00         2
# 34      0.00         3
# 35      0.00         2
# 37      0.00      1585
# 26      0.00         2
# 38      0.00      6540
# 39      0.00       500
# 40      0.00        16
# 41      0.00      6087
# 42      0.00      6982
# 43      0.00         5
# 44      0.00         3
# 45      0.00         2
# 46      0.00        81
# 47      0.00      3438
# 27      0.00         2
# 0       0.00      7043
# 1       0.00         2
# 11      0.00      1626
# 2       0.00        62
# 3       0.00         2
# 4       0.00         2
# 5       0.00         2
# 6       0.00         2
# 7       0.00        10
# 8       0.00         1
# 9       0.00         1
# 10      0.00      1106
# 12      0.00      1626
# 23      0.00         2
# 13      0.00      1625
# 14      0.00      1569
# 15      0.00         1
# 16      0.00         2
# 17      0.00        12
# 18      0.00        72
# 20      0.00         2
# 21      0.00      3584
# 22      0.00         2
# 25      0.00        50

# %%
profile_df[profile_df["null_count"] > 0].sort_values(by="null_count", ascending=False)
# Out:
#             column   dtype  non_null_count  null_count  null_pct  n_unique
# 48  Churn Category  object            1869        5174     73.46         6
# 49    Churn Reason  object            1869        5174     73.46        21
# 19           Offer  object            3166        3877     55.05         6
# 24   Internet Type  object            5517        1526     21.67         4

# %%
profile_df.sort_values(by="n_unique", ascending=False).head(15)
# Out:
#                                column    dtype  non_null_count  null_count  \
# 0                         Customer ID   object            7043           0
# 42                      Total Revenue  float64            7043           0
# 38                      Total Charges  float64            7043           0
# 41        Total Long Distance Charges  float64            7043           0
# 21  Avg Monthly Long Distance Charges  float64            7043           0
# 47                               CLTV    int64            7043           0
# 11                           Zip Code    int64            7043           0
# 12                           Latitude  float64            7043           0
# 13                          Longitude  float64            7043           0
# 37                     Monthly Charge  float64            7043           0
# 14                         Population    int64            7043           0
# 10                               City   object            7043           0
# 39                      Total Refunds  float64            7043           0
# 46                        Churn Score    int64            7043           0
# 18                   Tenure in Months    int64            7043           0
#
#     null_pct  n_unique
# 0        0.0      7043
# 42       0.0      6982
# 38       0.0      6540
# 41       0.0      6087
# 21       0.0      3584
# 47       0.0      3438
# 11       0.0      1626
# 12       0.0      1626
# 13       0.0      1625
# 37       0.0      1585
# 14       0.0      1569
# 10       0.0      1106
# 39       0.0       500
# 46       0.0        81
# 18       0.0        72

# %% [markdown]
# ## Initial Profiling Interpretation
#
# The profiling table reveals several important early patterns in the dataset.
#
# ### Observations
# - Most columns do not contain missing values.
# - Missingness is concentrated in a small number of columns, especially `Churn Reason`, `Churn Category`, `Offer`, and `Internet Type`.
# - Some columns have very high cardinality, such as `Customer ID`, `Total Charges`, `Total Revenue`, and location-related fields.
# - Several columns have only a small number of unique values, which suggests that the dataset contains many binary or categorical variables.

# %% [markdown]
# ## Duplicate Check
#
# Before moving further, we check whether the dataset contains fully duplicated rows.
#
# This is important because duplicate records can distort both analysis and model training.

# %%
print("Duplicate rows:", df.duplicated().sum())
# Out:
# Duplicate rows: 0

# %% [markdown]
# ## Duplicate Check Interpretation
#
# The dataset does not appear to contain fully duplicated rows.
#
# This is a positive early signal for data quality, since exact duplicates can distort both descriptive analysis and predictive modeling.
#
# At this stage, no further action is needed regarding row-level duplication.

# %% [markdown]
# ## Column Type Overview
#
# Here we separate columns into:
# - categorical columns
# - numeric columns
#
# This is an early structural step that will later help us with EDA, preprocessing, and modeling.

# %%
categorical_cols = df.select_dtypes(include=["object"]).columns.tolist()
numeric_cols = df.select_dtypes(include=[np.number]).columns.tolist()

print("Number of categorical columns:", len(categorical_cols))
print("Number of numeric columns:", len(numeric_cols))

print("\nCategorical columns:")
print(categorical_cols)

print("\nNumeric columns:")
print(numeric_cols)
# Out:
# Number of categorical columns: 31
# Number of numeric columns: 19
#
# Categorical columns:
# ['Customer ID', 'Gender', 'Under 30', 'Senior Citizen', 'Married', 'Dependents', 'Country', 'State', 'City', 'Quarter', 'Referred a Friend', 'Offer', 'Phone Service', 'Multiple Lines', 'Internet Service', 'Internet Type', 'Online Security', 'Online Backup', 'Device Protection Plan', 'Premium Tech Support', 'Streaming TV', 'Streaming Movies', 'Streaming Music', 'Unlimited Data', 'Contract', 'Paperless Billing', 'Payment Method', 'Customer Status', 'Churn Label', 'Churn Category', 'Churn Reason']
#
# Numeric columns:
# ['Age', 'Number of Dependents', 'Zip Code', 'Latitude', 'Longitude', 'Population', 'Number of Referrals', 'Tenure in Months', 'Avg Monthly Long Distance Charges', 'Avg Monthly GB Download', 'Monthly Charge', 'Total Charges', 'Total Refunds', 'Total Extra Data Charges', 'Total Long Distance Charges', 'Total Revenue', 'Satisfaction Score', 'Churn Score', 'CLTV']

# %% [markdown]
# ## Column Type Interpretation
#
# The dataset contains a mix of categorical and numeric columns:
# - 31 categorical columns
# - 19 numeric columns
#
# This suggests that the dataset is structurally suitable for a classification workflow, but it will require separate handling of categorical and numeric features during preprocessing.
#
# At this stage, this separation is only structural and does not yet determine which columns will be used for modeling.

# %% [markdown]
# ## Initial Inspection of Churn-Related Columns
#
# At this stage, we do not decide which column is the final target.
#
# We only inspect columns whose names suggest a connection to churn, status, or customer identity.
# This helps us identify:
# - possible target columns
# - possible identifier columns
# - possible post-outcome or leakage columns

# %%
suspect_cols = ["Customer ID", "Customer Status", "Churn Label", "Churn Category", "Churn Reason", "Churn Score"]

for col in suspect_cols:
    print(f"\n--- {col} ---")
    display(df[col].value_counts(dropna=False).head(10))
# Out:
# --- Customer ID ---
# Customer ID
# 8779-QRDMV    1
# 9817-APLHW    1
# 5447-VYTKW    1
# 8871-JLMHM    1
# 7029-IJEJK    1
# 4536-PLEQY    1
# 6923-AQONU    1
# 1335-HQMKX    1
# 4616-EWBNJ    1
# 0384-LPITE    1
# Name: count, dtype: int64
# --- Customer Status ---
# Customer Status
# Stayed     4720
# Churned    1869
# Joined      454
# Name: count, dtype: int64
# --- Churn Label ---
# Churn Label
# No     5174
# Yes    1869
# Name: count, dtype: int64
# --- Churn Category ---
# Churn Category
# NaN                5174
# Competitor          841
# Attitude            314
# Dissatisfaction     303
# Price               211
# Other               200
# Name: count, dtype: int64
# --- Churn Reason ---
# Churn Reason
# NaN                                          5174
# Competitor had better devices                 313
# Competitor made better offer                  311
# Attitude of support person                    220
# Don't know                                    130
# Competitor offered more data                  117
# Competitor offered higher download speeds     100
# Attitude of service provider                   94
# Price too high                                 78
# Product dissatisfaction                        77
# Name: count, dtype: int64
# --- Churn Score ---
# Churn Score
# 91    202
# 80    150
# 71    148
# 77    145
# 67    142
# 76    140
# 68    140
# 90    139
# 69    138
# 70    138
# Name: count, dtype: int64

# %% [markdown]
# ## Churn-Related Columns Interpretation
#
# The dataset contains several columns directly related to churn or customer status, including `Churn Label`, `Customer Status`, `Churn Category`, `Churn Reason`, and `Churn Score`.
#
# ### Early observations
# - `Churn Label` appears to be a binary field and may be a candidate target variable.
# - `Customer Status` appears to contain broader customer outcome categories.
# - `Churn Category` and `Churn Reason` contain substantial missingness and seem to be available only for a subset of customers.
# - `Churn Score` may represent a derived or model-generated quantity rather than a raw business feature.
#
# ### Important note
# These columns require deeper inspection before any modeling decision is made, especially to determine whether some of them may introduce leakage or post-outcome information.

# %% [markdown]
# ## Initial Notes
#
# At this point, we only record early observations.
#
# Possible areas for further inspection:
# - likely target column(s)
# - identifier column(s)
# - possible leakage columns
# - columns with high missingness
# - columns that may need datatype correction
#
# No cleaning or modeling decisions are made yet.
